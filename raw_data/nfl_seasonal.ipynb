# %%
# import packages
import pandas as pd
import plotly.graph_objects as go
import nfl_data_py as nfl

# %%
df_seasonal_2022 =nfl.import_seasonal_data([2022], 'ALL')

# %%
display(df_seasonal_2022)
# Out:
#       player_id  season season_type
# 0    00-0019596    2022        POST  \
# 1    00-0019596    2022         REG
# 2    00-0022824    2022         REG
# 3    00-0023459    2022         REG
# 4    00-0024243    2022         REG
# ..          ...     ...         ...
# 756  00-0038129    2022         REG
# 757  00-0038134    2022        POST
# 758  00-0038134    2022         REG
# 759  00-0038147    2022         REG
# 760  00-0038149    2022         REG
#
#                                            player_name
# 0                                              T.Brady  \
# 1    T.BradyT.BradyT.BradyT.BradyT.BradyT.BradyT.Br...
# 2                                                A.Lee
# 3    A.RodgersA.RodgersA.RodgersA.RodgersA.RodgersA...
# 4           M.LewisM.LewisM.LewisM.LewisM.LewisM.Lewis
# ..                                                 ...
# 756  C.OttonC.OttonC.OttonC.OttonC.OttonC.OttonC.Ot...
# 757                                           K.Walker
# ...
