# %%
## pip install --upgrade nfl_data_py
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for nfl_data_py: filename=nfl_data_py-0.3.1-py3-none-any.whl size=13224 sha256=1129d12dcfc12d4a14f66905d969f39dbbcdbe2478e07b20d9d7a2ab66445ef4
#   Stored in directory: c:\users\wiltse family\appdata\local\pip\cache\wheels\fe\11\b6\5bb8be8edf87539560c6ab0a33ea205b170c18ab5be747f601
# Successfully built nfl_data_py
# ...
#   Attempting uninstall: nfl_data_py
#     Found existing installation: nfl-data-py 0.3.0
#     Uninstalling nfl-data-py-0.3.0:
#       Successfully uninstalled nfl-data-py-0.3.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# import packages
import pandas as pd
import nfl_data_py as nfl

# %%
#Get weekly data for 2022 season
df_weekly_rosters_2022 = nfl.import_weekly_rosters([2022])

# %%
filtered_df = df_weekly_rosters_2022[(df_weekly_rosters_2022['player_name'] == 'Tom Brady') ]

# %%
display(filtered_df)
# Out:
#     season team position depth_chart_position  jersey_number status
# 0     2022   TB       QB                   QB           12.0    ACT  \
# 1     2022   TB       QB                   QB           12.0    ACT
# 2     2022   TB       QB                   QB           12.0    ACT
# 3     2022   TB       QB                   QB           12.0    ACT
# 4     2022   TB       QB                   QB           12.0    ACT
# 5     2022   TB       QB                   QB           12.0    ACT
# 6     2022   TB       QB                   QB           12.0    ACT
# 7     2022   TB       QB                   QB           12.0    ACT
# 8     2022   TB       QB                   QB           12.0    ACT
# 9     2022   TB       QB                   QB           12.0    ACT
# 10    2022   TB       QB                   QB           12.0    ACT
# 11    2022   TB       QB                   QB           12.0    ACT
# 12    2022   TB       QB                   QB           12.0    ACT
# ...

# %%
#Get weekly data for 2022 season
df_seasonal_rosters_2022 = nfl.import_seasonal_rosters([2022])

# %%
filtered_df = df_seasonal_rosters_2022[(df_seasonal_rosters_2022['player_name'] == 'Tom Brady') ]

# %%
display(filtered_df)
# Out:
#    season team position depth_chart_position  jersey_number status
# 0    2022   TB       QB                   QB           12.0    ACT  \
#
#   player_name first_name last_name birth_date  ...  status_description_abbr
# 0   Tom Brady        Tom     Brady 1977-08-03  ...                      A01  \
#
#    football_name     esb_id gsis_it_id                              smart_id
# 0            Tom  BRA371156      25511  32004252-4137-1156-7ed0-8b9e44948f13  \
#
#   entry_year rookie_year draft_club draft_number   age
# 0       2000      2000.0         NE        199.0  45.0
#
# [1 rows x 37 columns]

# %%
nfl_ids = nfl.import_ids()

# %%
display(nfl_ids)
# Out:
#        mfl_id                         sportradar_id  fantasypros_id
# 0       15702  93147c90-09c8-471d-a6b2-0b9d19739ba1         24740.0  \
# 1       16148  38475bfa-9773-4c3b-9157-a0dbd576fa22         22900.0
# 2       16149  4c8a2f7e-f982-4eca-9d52-cf53df6985a4         22987.0
# 3       16150  7e91086f-9ca4-4bd9-a099-b88b2f37e6c6         23071.0
# 4       16151  25b10007-802d-4ebb-8314-3eb7b24ddc37         24332.0
# ...       ...                                   ...             ...
# 11377     972                                   NaN             NaN
# 11378     978                                   NaN             NaN
# 11379     984                                   NaN             NaN
# 11380     990                                   NaN             NaN
# 11381     996                                   NaN             NaN
#
#           gsis_id  pff_id  sleeper_id nfl_id  espn_id  yahoo_id
# 0      00-0038400     NaN      9230.0    NaN      NaN   40220.0  \
# ...

# %%
filtered_df = nfl_ids[(nfl_ids['nfl_id'] == 'tombrady/2504211') ]

# %%
display(filtered_df)
# Out:
#       mfl_id                         sportradar_id  fantasypros_id
# 8200    5848  41c44740-d0f6-44ab-8347-3b5d515e5ecf          9603.0  \
#
#          gsis_id  pff_id  sleeper_id            nfl_id  espn_id  yahoo_id
# 8200  00-0019596   698.0       167.0  tombrady/2504211   2330.0    5228.0  \
#
#       fleaflicker_id  ...   age draft_year draft_round  draft_pick  draft_ovr
# 8200           309.0  ...  46.3     2000.0         6.0        33.0      199.0  \
#
#       twitter_username  height  weight   college  db_season
# 8200               NaN    76.0   225.0  Michigan       2023
#
# [1 rows x 35 columns]
