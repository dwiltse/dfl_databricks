# %%
pip install --upgrade nfl_data_py
# Out:
# Requirement already satisfied: nfl_data_py in c:\users\wiltse family\.conda\envs\base2\lib\site-packages (0.3.0)
# Collecting nfl_data_py
#   Downloading nfl_data_py-0.3.1.tar.gz (16 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pandas>1 in c:\users\wiltse family\.conda\envs\base2\lib\site-packages (from nfl_data_py) (2.0.0)
# Requirement already satisfied: appdirs>1 in c:\users\wiltse family\.conda\envs\base2\lib\site-packages (from nfl_data_py) (1.4.4)
# Requirement already satisfied: fastparquet>0.5 in c:\users\wiltse family\.conda\envs\base2\lib\site-packages (from nfl_data_py) (2023.2.0)
# Requirement already satisfied: python-snappy>0.5 in c:\users\wiltse family\.conda\envs\base2\lib\site-packages (from nfl_data_py) (0.6.1)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\wiltse family\appdata\roaming\python\python38\site-packages (from fastparquet>0.5->nfl_data_py) (1.24.2)
# Requirement already satisfied: fsspec in c:\users\wiltse family\.conda\envs\base2\lib\site-packages (from fastparquet>0.5->nfl_data_py) (2023.3.0)
# Requirement already satisfied: cramjam>=2.3 in c:\users\wiltse family\.conda\envs\base2\lib\site-packages (from fastparquet>0.5->nfl_data_py) (2.6.2)
# Requirement already satisfied: packaging in c:\users\wiltse family\.conda\envs\base2\lib\site-packages (from fastparquet>0.5->nfl_data_py) (23.0)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\wiltse family\.conda\envs\base2\lib\site-packages (from pandas>1->nfl_data_py) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\wiltse family\.conda\envs\base2\lib\site-packages (from pandas>1->nfl_data_py) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\wiltse family\.conda\envs\base2\lib\site-packages (from pandas>1->nfl_data_py) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\wiltse family\.conda\envs\base2\lib\site-packages (from python-dateutil>=2.8.2->pandas>1->nfl_data_py) (1.16.0)
# Building wheels for collected packages: nfl_data_py
#   Building wheel for nfl_data_py (setup.py): started
#   Building wheel for nfl_data_py (setup.py): finished with status 'done'
#   Created wheel for nfl_data_py: filename=nfl_data_py-0.3.1-py3-none-any.whl size=13224 sha256=1129d12dcfc12d4a14f66905d969f39dbbcdbe2478e07b20d9d7a2ab66445ef4
#   Stored in directory: c:\users\wiltse family\appdata\local\pip\cache\wheels\fe\11\b6\5bb8be8edf87539560c6ab0a33ea205b170c18ab5be747f601
# Successfully built nfl_data_py
# Installing collected packages: nfl_data_py
#   Attempting uninstall: nfl_data_py
#     Found existing installation: nfl-data-py 0.3.0
#     Uninstalling nfl-data-py-0.3.0:
#       Successfully uninstalled nfl-data-py-0.3.0
# Successfully installed nfl_data_py-0.3.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# import packages
import pandas as pd
import nfl_data_py as nfl

# %%
#Get weekly data for 2022 season
df_weekly_rosters_2022 = nfl.import_weekly_rosters([2022])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Wiltse Family\Documents\databricks\dfl_databricks_github\dfl_databricks-1\raw_data\nfl_weekly_rosters.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Wiltse%20Family/Documents/databricks/dfl_databricks_github/dfl_databricks-1/raw_data/nfl_weekly_rosters.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> #Get weekly data for 2022 season
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Wiltse%20Family/Documents/databricks/dfl_databricks_github/dfl_databricks-1/raw_data/nfl_weekly_rosters.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> df_weekly_rosters_2022 = nfl.import_weekly_rosters([2022])
#
# AttributeError: module 'nfl_data_py' has no attribute 'import_weekly_rosters'

# %%
display(df_weekly_rosters_2022)
# Out:
#       season team position depth_chart_position  jersey_number status
# 0       2022   TB       QB                   QB           12.0    ACT  \
# 1       2022  DAL       OL                    T           71.0    INA
# 2       2022  ARI        P                    P           14.0    ACT
# 3       2022   SF        K                    K            9.0    ACT
# 4       2022   GB       QB                   QB           12.0    ACT
# ...      ...  ...      ...                  ...            ...    ...
# 3129    2022   NE       LB                   LB           59.0    CUT
# 3130    2022  CLE       WR                   WR           17.0    DEV
# 3131    2022  CHI       OL                    C           59.0    CUT
# 3132    2022  ATL       WR                   WR           80.0    ACT
# 3133    2022  JAX       QB                   QB            NaN    RES
#
#          player_name first_name last_name birth_date  ...  game_type
# 0          Tom Brady        Tom     Brady 1977-08-03  ...         WC  \
# 1       Jason Peters      Jason    Peters 1982-01-22  ...        DIV
# 2           Andy Lee       Andy       Lee 1982-08-11  ...        REG
# 3       Robbie Gould     Robbie     Gould 1982-12-06  ...        CON
# 4      Aaron Rodgers      Aaron   Rodgers 1983-12-02  ...        REG
# ...              ...        ...       ...        ...  ...        ...
# 3129    Nate Wieland       Nate   Wieland        NaT  ...        REG
# 3130  Daylen Baldwin     Daylen   Baldwin 1999-11-24  ...        REG
# 3131    Corey Dublin      Corey    Dublin        NaT  ...        REG
# 3132        Josh Ali       Josh       Ali 1999-03-03  ...        REG
# 3133   Nathan Rourke     Nathan    Rourke        NaT  ...        DIV
#
#       status_description_abbr football_name     esb_id gsis_it_id
# 0                         A01           Tom  BRA371156      25511  \
# 1                         A01         Jason  PET150539      29550
# 2                         A01          Andy  LEE008195      29141
# 3                         A01        Robbie  GOU258729      30403
# 4                         A01         Aaron  ROD339293      29851
# ...                       ...           ...        ...        ...
# 3129                      W03          Nate  WIE401495      55432
# 3130                      P01        Daylen  BAL305182      55503
# 3131                      W03         Corey  DUB247039      55548
# 3132                      A01          Josh  ALI103821      55557
# 3133                      R23        Nathan       None      54152
#
#                                   smart_id entry_year rookie_year draft_club
# 0     32004252-4137-1156-7ed0-8b9e44948f13       2000      2000.0         NE  \
# 1     32005045-5415-0539-96c0-31361312950f       2004      2004.0       None
# 2     32004c45-4500-8195-3f84-7c9db88c8928       2004      2004.0         SF
# 3     3200474f-5525-8729-db48-d9e3a46235a3       2005      2005.0       None
# 4     3200524f-4433-9293-a3cf-ad7758d03003       2005      2005.0         GB
# ...                                    ...        ...         ...        ...
# 3129  32005749-4540-1495-e89d-28c87c2a4dca       2022      2022.0       None
# 3130  32004241-4c30-5182-cce9-a43158f7cd58       2022      2022.0       None
# 3131  32004455-4224-7039-763d-a7e376e99a18       2022      2022.0       None
# 3132  3200414c-4910-3821-d8c6-6a2f067ca6cc       2022      2022.0       None
# 3133                                  None       2020         NaN       None
#
#      draft_number
# 0           199.0
# 1             NaN
# 2           188.0
# 3             NaN
# 4            24.0
# ...           ...
# 3129          NaN
# 3130          NaN
# 3131          NaN
# 3132          NaN
# 3133          NaN
#
# [3134 rows x 36 columns]

# %%
nfl_ids = nfl.import_ids(columns, ids)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Wiltse Family\Documents\databricks\dfl_databricks_github\dfl_databricks-1\raw_data\nfl_weekly_rosters.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Wiltse%20Family/Documents/databricks/dfl_databricks_github/dfl_databricks-1/raw_data/nfl_weekly_rosters.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> nfl_ids = nfl.import_ids(columns, ids)
#
# NameError: name 'columns' is not defined
